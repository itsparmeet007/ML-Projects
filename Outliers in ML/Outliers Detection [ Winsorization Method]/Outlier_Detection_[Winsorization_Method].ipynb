# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/weight-height.csv')
df.sample(4)
# Out:
#       Gender     Height      Weight
# 196     Male  67.253325  180.779780
# 5306  Female  62.070396  119.298987
# 8288  Female  65.740253  165.156371
# 8008  Female  59.244646  104.918826

# %%
df.shape
# Out:
# (10000, 3)

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['Height'])

plt.subplot(2,2,2)
sns.boxplot(df['Height'])
plt.show()

# %%
upper_limit = df['Height'].quantile(0.99)
lower_limit = df['Height'].quantile(0.01)
print(upper_limit)
print(lower_limit)
# Out:
# 74.7857900583366
# 58.13441158671655

# %%
df[(df['Height'] >= 74.78) | (df['Height'] <= 58.13 )]
# Out:
#       Gender     Height      Weight
# 23      Male  75.205974  228.761781
# 190     Male  76.709835  235.035419
# 197     Male  75.944460  231.924749
# 202     Male  75.140821  224.124271
# 215     Male  74.795375  232.635403
# ...      ...        ...         ...
# 9761  Female  56.975279   90.341784
# 9825  Female  55.979198   85.417534
# 9895  Female  57.740192   93.652957
# 9904  Female  57.028857  101.202551
# 9978  Female  57.375759  114.192209
#
# [201 rows x 3 columns]

# %% [markdown]
# # **Trimming**

# %%
new_df = df[(df['Height'] <= 74.78) & (df['Height'] >= 58.13 )]

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
new_df['Height'].describe()
# Out:
# count    9799.000000
# mean       66.363507
# std         3.644267
# min        58.134496
# 25%        63.577147
# 50%        66.317899
# 75%        69.119859
# max        74.767447
# Name: Height, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(new_df['Height'])

plt.subplot(2,2,2)
sns.boxplot(new_df['Height'])
plt.show()

# %% [markdown]
# **More the data you will take as an percentile like here we have taken 0.99 and 0.01 . Very Less data will be removed**

# %%
#Capping --> Winsorization

df ['Height'] = np.where(
    df['Height'] >= upper_limit,
    upper_limit,
    np.where(df['Height'] <= lower_limit,
             lower_limit,
             df['Height']))

# %%
df.shape
# Out:
# (10000, 3)

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.366281
# std          3.795717
# min         58.134412
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         74.785790
# Name: Height, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['Height'])

plt.subplot(2,2,2)
sns.boxplot(df['Height'])
plt.show()
